# %%
import pandas as pd
import numpy as np
import tqdm
from tqdm import tqdm
from tqdm import trange

# %%
data = pd.read_csv('zlxt.csv')
data.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1, inplace=True)
data
# Out:
#                    店铺名称           用户名  \
# 0     众里寻她·千百度自助烤肉（温江店）            蕙蓉
# 1     众里寻她·千百度自助烤肉（温江店）  Fte337417584
# 2     众里寻她·千百度自助烤肉（温江店）  lKI727919841
# 3     众里寻她·千百度自助烤肉（温江店）  ncH155212901
# 4     众里寻她·千百度自助烤肉（温江店）  hJy941251704
# ...                 ...           ...
# 2471  众里寻她·千百度自助烤肉（温江店）  QmZ247891955
# 2472  众里寻她·千百度自助烤肉（温江店）         知道身份么
# 2473  众里寻她·千百度自助烤肉（温江店）          匿名用户
# 2474  众里寻她·千百度自助烤肉（温江店）          匿名用户
# 2475  众里寻她·千百度自助烤肉（温江店）  KeO238205193
#
#                                                      评论
# 0                      来了很多次了，不错，这个价位真的算性价比超高了，朋友聚会确实划算
# 1                        这个价格自助餐很少了，而且菜品多，菜也新鲜，位置好。值得再去
# 2                                                   都挺好
# 3                                                   美滋滋
# 4                                             菜品很多，饮料很多
# ...                                                 ...
# 2471                                    不错，不错，不错。强烈推荐去吃
# ...

# %%
words = [
 ('好吃', 473),
 ('新鲜', 334),
 ('服务', 329),
 ('环境', 308),
 ('五花肉', 245),
 ('烤肉', 240),
 ('没有', 224),
 ('喜欢', 218),
 ('感觉', 214),
 ('水果', 182),
 ('生意', 175),
 ('价格', 162),
 ('种类', 162),
 ('鸡翅', 161),
 ('有点', 158),
 ('服务态度', 156),
 ('推荐', 154),
 ('实惠', 141),
 ('肥牛', 139),
 ('服务员', 131),
 ('饮料', 124),
 ('性价比', 120),
 ('西瓜', 118),
 ('值得', 114),
 ('位置', 113),
 ('自助', 113),
 ('还有', 110),
 ('鸡腿', 110),
 ('口味', 110),
 ('觉得', 108),
 ('蔬菜', 98),
 ('还好', 94),
 ('小吃', 92),
 ('态度', 90),
 ('希望', 88),
 ('味碟', 86),
 ('江南', 84),
 ('朋友', 82),
 ('热情', 80),
 ('适合', 78),
 ('东西', 72),
 ('时候', 69),
 ('扇贝', 68),
 ('聚餐', 68),
 ('可能', 64),
 ('划算', 62),
 ('满意', 62),
 ('排队', 60),
 ('鸡蛋', 60),
 ('品种', 58),
 ('老板', 58),
 ('海鲜', 58),
 ('总体', 56),
 ('肉类', 55),
 ('果汁', 52),
 ('还行', 52),
 ('冰激凌', 49),
 ('地方', 49),
 ('泡芙', 46),
 ('学生', 44),
 ('牛肉', 44),
 ('煎蛋', 44),
 ('涨价', 38),
 ('知道', 38),
 ('好找', 37),
 ('提前', 36),
 ('温江', 34),
 ('生菜', 34),
 ('藕片', 32),
 ('装修', 32),
 ('改进', 30),
 ('整体', 30),
 ('单人', 30),
 ('需要', 30),
 ('炸鸡翅', 30),
 ('大家', 30),
 ('凉面', 30),
 ('个人', 30),
 ('火腿', 30),
 ('店家', 28),
 ('聚会', 28),
 ('选择', 28),
 ('等位', 28),
 ('店里', 28),
 ('就餐', 28),
 ('拉肚子', 28),
 ('爆满', 26),
 ('二楼', 26),
 ('不会', 25),
 ('开心', 24),
 ('评价', 24),
 ('套餐', 24),
 ('鱿鱼', 24),
 ('原因', 24),
 ('甜点', 24),
 ('大学城', 24),
 ('同学', 24),
 ('吃饭', 24),
 ('洋葱', 22),
 ('烤肉店', 22),
 ('甜品', 22),
 ('自助餐', 22),
 ('大学', 22),
 ('人气', 22),
 ('棒棒', 22),
 ('男朋友', 22),
 ('建议', 22),
 ('蛋糕', 20),
 ('起来', 20),
 ('出来', 20),
 ('室友', 20),
 ('开始', 20),
 ('周到', 20),
 ('只能', 20),
 ('美团', 19),
 ('桌子', 18),
 ('好喝', 18),
 ('爆好', 18),
 ('增加', 18),
 ('消费', 18),
 ('价钱', 18),
 ('方面', 18),
 ('粉丝', 18),
 ('应该', 18),
 ('看到', 18),
 ('经济', 17),
 ('安排', 16),
 ('圣女', 16),
 ('不行', 16),
 ('小时', 16),
 ('客人', 16),
 ('鹌鹑蛋', 16),
 ('预约', 16),
 ('体验', 16),
 ('酱料', 16),
 ('尝试', 16),
 ('价格便宜', 16),
 ('饮品', 16),
 ('结果', 16),
 ('回去', 16),
 ('机会', 16),
 ('免费', 16),
 ('鸡皮', 16),
 ('一楼', 14),
 ('学校', 14),
 ('鸡肉', 14),
 ('荤菜', 14),
 ('不能', 14),
 ('超好', 14),
 ('好看', 14),
 ('吃到', 14),
 ('鸭肠', 14),
 ('调料', 14),
 ('新尚', 14),
 ('团购', 14),
 ('基本', 14),
 ('寝室', 14),
 ('改善', 14),
 ('不太好', 14),
 ('大湾', 14),
 ('烧烤', 14),
 ('有待', 14),
 ('不算', 13),
 ('好评', 13),
 ('辣椒面', 12),
 ('一家人', 12),
 ('合理', 12),
 ('到位', 12),
 ('不够', 12),
 ('继续', 12),
 ('包蛋', 12),
 ('肚子', 12),
 ('凉菜', 12),
 ('店面', 12),
 ('毕业', 12),
 ('奶茶', 12),
 ('好像', 12),
 ('样式', 12),
 ('盘子', 12),
 ('天地', 12),
 ('能够', 12),
 ('座位', 12),
 ('专门', 12),
 ('补充', 12),
 ('成都', 12),
 ('预定', 12),
 ('回来', 12),
 ('用餐', 12),
 ('素菜', 12),
 ('光顾', 12),
 ('超高', 12),
 ('熟食', 12),
 ('老板娘', 12),
 ('品质', 10),
 ('油烟', 10),
 ('首选', 10),
 ('腌制', 10),
 ('价位', 10),
 ('炭火', 10),
 ('品尝', 10),
 ('酒水', 10),
 ('食物', 10),
 ('试试', 10),
 ('土豆', 10),
 ('同事', 10),
 ('想象', 10),
 ('点心', 10),
 ('回头客', 10),
 ('调味', 10),
 ('上菜', 10),
 ('满足', 10),
 ('点点', 10),
 ('排骨', 10),
 ('期待', 10),
 ('没洗', 10),
 ('看着', 10),
 ('肯定', 10),
 ('提高', 10),
 ('不用', 10),
 ('位子', 10),
 ('失望', 10),
 ('金针菇', 10),
 ('时间', 8),
 ('加上', 8),
 ('呵呵', 8),
 ('帮忙', 8),
 ('学期', 8),
 ('收费', 8),
 ('孩子', 8),
 ('小伙伴', 8),
 ('太小', 8),
 ('升级', 8),
 ('哥哥', 8),
 ('姐姐', 8),
 ('问题', 8),
 ('分量', 8),
 ('商家', 8),
 ('食材', 8),
 ('炸鸡', 8),
 ('婆婆', 8),
 ('算是', 8),
 ('空调', 8),
 ('异味', 8),
 ('椅子', 8),
 ('找到', 8),
 ('鳕鱼', 8),
 ('光临', 8),
 ('关键', 8),
 ('高峰期', 8),
 ('份量', 8),
 ('供应', 8),
 ('虾子', 8),
 ('小孩', 8),
 ('想念', 8),
 ('前台', 8),
 ('冰粉', 7),
 ('控制', 6),
 ('开学', 6),
 ('记得', 6),
 ('估计', 6),
 ('预订', 6),
 ('天气', 6),
 ('基本上', 6),
 ('样子', 6),
 ('个人感觉', 6),
 ('越做越', 6),
 ('理解', 6),
 ('一分货', 6),
 ('环境优美', 6),
 ('接受', 6),
 ('菜量', 6),
 ('作为', 6),
 ('店子', 6),
 ('照顾', 6),
 ('来讲', 6),
 ('吃撑', 6),
 ('食品', 6),
 ('要求', 6),
 ('东门', 6),
 ('辣椒', 6),
 ('超赞', 6),
 ('图片', 6),
 ('技术', 6),
 ('个别', 6),
 ('没了', 6),
 ('口感', 6),
 ('烤炉', 6),
 ('特色', 6),
 ('橘子', 6),
 ('上涨', 6),
 ('支持', 6),
 ('优惠', 6),
 ('寿司', 6),
 ('香菇', 6),
 ('配菜', 6),
 ('不想', 6),
 ('实在', 6),
 ('尝尝', 6),
 ('人员', 6),
 ('围裙', 6),
 ('程度', 6),
 ('看见', 6),
 ('薯条', 6),
 ('不到', 6),
 ('家人', 6),
 ('加强', 6),
 ('适中', 6),
 ('半价', 6),
 ('客流量', 6),
 ('购买', 6),
 ('不了', 6),
 ('试一试', 6),
 ('人暴', 6),
 ('饭点', 6),
 ('还算', 6),
 ('鲫鱼', 6),
 ('烤起来', 6),
 ('发现', 6),
 ('鱼片', 6),
 ('饱饱', 5),
 ('烤鱼', 5),
 ('太重', 4),
 ('遇到', 4),
 ('衣服', 4),
 ('自助餐厅', 4),
 ('懒猫', 4),
 ('不吃', 4),
 ('情调', 4),
 ('沙子', 4),
 ('臭味', 4),
 ('菜类', 4),
 ('妹儿', 4),
 ('有没有', 4),
 ('加油', 4),
 ('表示', 4),
 ('跟着', 4),
 ('太肥', 4),
 ('回家', 4),
 ('综合', 4),
 ('鱼皮', 4),
 ('露天', 4),
 ('超过', 4),
 ('比起', 4),
 ('总类', 4),
 ('入味', 4),
 ('买单', 4),
 ('礼貌', 4),
 ('没得', 4),
 ('可口', 4),
 ('地道', 4),
 ('适得', 4),
 ('就算', 4),
 ('韩国', 4),
 ('巴士', 4),
 ('牌子', 4),
 ('卫生条件', 4),
 ('黄瓜', 4),
 ('火候', 4),
 ('比价', 4),
 ('赞赞', 4),
 ('凉皮', 4),
 ('素质', 4),
 ('点菜', 4),
 ('对象', 4),
 ('鸡尖', 4),
 ('享受', 4),
 ('开业', 4),
 ('大厅', 4),
 ('蛋炒饭', 4),
 ('奶黄', 4),
 ('可惜', 4),
 ('招呼', 4),
 ('空气', 4),
 ('意见', 4),
 ('收盘', 4),
 ('需求', 4),
 ('叔叔', 4),
 ('头发', 4),
 ('亲们', 4),
 ('服务到位', 4),
 ('提醒', 4),
 ('点过', 4),
 ('妹妹', 4),
 ('超多', 4),
 ('烟味', 4),
 ('炸鸡腿', 4),
 ('做好', 4),
 ('年轻人', 4),
 ('无敌', 4),
 ('变味', 4),
 ('中翅', 4),
 ('进去', 4),
 ('感受', 4),
 ('吓到', 4),
 ('活动', 4),
 ('是从', 4),
 ('空间', 4),
 ('肚子痛', 4),
 ('进行', 4),
 ('热心', 4),
 ('读书', 4),
 ('美美', 4),
 ('坐满', 4),
 ('提出', 4),
 ('冰冻', 4),
 ('变得', 4),
 ('蛋黄', 4),
 ('认可', 4),
 ('螃蟹', 4),
 ('收银', 4),
 ('辣椒粉', 4),
 ('春卷', 4),
 ('全部', 4),
 ('鸡棒', 4),
 ('肉肉', 4),
 ('肌肉', 4),
 ('付钱', 4),
 ('机器', 4),
 ('瓶装', 4),
 ('脑花', 4),
 ('疫情', 4),
 ('卖家', 4),
 ('风扇', 4),
 ('看起来', 4),
 ('难过', 4),
 ('一分钱', 4),
 ('考虑', 4),
 ('餐椅', 4),
 ('腥味', 4),
 ('选择性', 4),
 ('醪糟', 4),
 ('走过', 4),
 ('离开', 4),
 ('极差', 4),
 ('公道', 4),
 ('宿舍', 4),
 ('儿子', 4),
 ('大众', 4),
 ('贝壳类', 4),
 ('现场', 4),
 ('质量', 4),
 ('挺快', 4),
 ('类型', 4),
 ('晚餐', 4),
 ('酸奶', 4),
 ('上买', 4),
 ('准备', 4),
 ('餐盘', 4),
 ('小菜', 4),
 ('美女', 4),
 ('火锅', 4),
 ('影响', 4),
 ('蛤蜊', 4),
 ('基围', 4),
 ('处理', 4),
 ('排号', 4),
 ('眼睛', 4),
 ('离家近', 4),
 ('记忆', 4),
 ('说好', 4),
 ('特地', 4),
 ('强力', 4),
 ('板凳', 4),
 ('价格公道', 4),
 ('馒头', 4),
 ('等候', 4),
 ('回忆', 4),
 ('食欲', 4),
 ('路过', 4),
 ('青口', 4),
 ('换成', 4),
 ('晓得', 4),
 ('工作人员', 4),
 ('提升', 4),
 ('小心', 4),
 ('甜面酱', 4),
 ('怀念', 4),
 ('下单', 3),
 ('烤鸡', 3),
 ('菜式', 3),
 ('人家', 3),
 ('掌握', 2),
 ('不厌', 2),
 ('记不住', 2),
 ('次数', 2),
 ('难受', 2),
 ('全价', 2),
 ('打不开', 2),
 ('筷子', 2),
 ('大排', 2),
 ('想去', 2),
 ('工作', 2),
 ('管道', 2),
 ('想着', 2),
 ('整理', 2),
 ('子收', 2),
 ('满满', 2),
 ('出钱', 2),
 ('居住', 2),
 ('没来', 2),
 ('吃货', 2),
 ('检查一下', 2),
 ('说来', 2),
 ('包吃', 2),
 ('规模', 2),
 ('没去', 2),
 ('性子', 2),
 ('在于', 2),
 ('班级', 2),
 ('鸡翅膀', 2),
 ('鼓励', 2),
 ('肉质', 2),
 ('想法', 2),
 ('出去', 2),
 ('数量', 2),
 ('讲完', 2),
 ('标签', 2),
 ('红火', 2),
 ('冲动', 2),
 ('肠胃炎', 2),
 ('押金', 2),
 ('吃味', 2),
 ('细心', 2),
 ('有钱', 2),
 ('计费', 2),
 ('雨棚', 2),
 ('少印', 2),
 ('油差', 2),
 ('豆瓣酱', 2),
 ('烤肠', 2),
 ('了比', 2),
 ('懒得', 2),
 ('火来', 2),
 ('需不需要', 2),
 ('息怒', 2),
 ('淡点', 2),
 ('地理环境', 2),
 ('凉拌', 2),
 ('担心', 2),
 ('慎入', 2),
 ('吃够', 2),
 ('大学生', 2),
 ('相间', 2),
 ('注水肉', 2),
 ('厕所', 2),
 ('试一下', 2),
 ('宣传', 2),
 ('关注', 2),
 ('店大欺客', 2),
 ('档次', 2),
 ('洗脸', 2),
 ('零食', 2),
 ('效果', 2),
 ('无烟', 2),
 ('堂子', 2),
 ('所有人', 2),
 ('相应', 2),
 ('频率', 2),
 ('掉下来', 2),
 ('对面', 2),
 ('足下', 2),
 ('抽烟', 2),
 ('酱油', 2),
 ('骨头', 2),
 ('超香', 2),
 ('做得好', 2),
 ('好玩', 2),
 ('恋爱', 2),
 ('女朋友', 2),
 ('太火', 2),
 ('配合', 2),
 ('确是', 2),
 ('小孩子', 2),
 ('总结', 2),
 ('打湿', 2),
 ('处于', 2),
 ('速度', 2),
 ('减肥', 2),
 ('油纸', 2),
 ('反复', 2),
 ('水准', 2),
 ('对方', 2),
 ('用电', 2),
 ('烧焦', 2),
 ('指着', 2),
 ('状态', 2),
 ('烤者', 2),
 ('小子', 2),
 ('大气', 2),
 ('大虾', 2),
 ('密闭', 2),
 ('女生', 2),
 ('毛线', 2),
 ('道癌', 2),
 ('烤盘', 2),
 ('比电', 2),
 ('品味', 2),
 ('变化', 2),
 ('差距', 2),
 ('外地', 2),
 ('点赞', 2),
 ('加盟', 2),
 ('卤味', 2),
 ('奶思', 2),
 ('行事', 2),
 ('欧克', 2),
 ('人流量', 2),
 ('变多', 2),
 ('老婆', 2),
 ('垃圾', 2),
 ('亏本', 2),
 ('油太', 2),
 ('材料', 2),
 ('羊排', 2),
 ('方向', 2),
 ('加菜', 2),
 ('小火锅', 2),
 ('来放', 2),
 ('宏图', 2),
 ('火气', 2),
 ('肉感', 2),
 ('混料', 2),
 ('来不及', 2),
 ('温度', 2),
 ('地点', 2),
 ('姐妹', 2),
 ('大堂', 2),
 ('笑容', 2),
 ('失落', 2),
 ('丝竹', 2),
 ('喷完', 2),
 ('代替', 2),
 ('鸭架', 2),
 ('串味', 2),
 ('单调', 2),
 ('小朋友', 2),
 ('贝类', 2),
 ('管理', 2),
 ('小点', 2),
 ('实数', 2),
 ('赶脚', 2),
 ('做到', 2),
 ('吐出来', 2),
 ('作用', 2),
 ('貌似', 2),
 ('红店', 2),
 ('速冻', 2),
 ('起床', 2),
 ('厨房', 2),
 ('经验', 2),
 ('客服', 2),
 ('女士', 2),
 ('菜存', 2),
 ('注意事项', 2),
 ('电视', 2),
 ('热饮', 2),
 ('儿童', 2),
 ('干饭', 2),
 ('菜叶', 2),
 ('增添', 2),
 ('带来', 2),
 ('烤翅类', 2),
 ('通风', 2),
 ('空余', 2),
 ('品牌', 2),
 ('人用', 2),
 ('搭理', 2),
 ('锁上', 2)
]

# %%
words = [('环境', 58),
 ('服务', 52),
 ('新鲜', 46),
 ('服务员', 44),
 ('态度', 40),
 ('烤肉', 32),
 ('知道', 30),
 ('饮料', 29),
 ('还有', 27),
 ('东西', 26),
 ('位置', 26),
 ('时候', 26),
 ('水果', 25),
 ('种类', 24),
 ('西瓜', 22),
 ('不行', 22),
 ('服务态度', 22),
 ('觉得', 22),
 ('价格', 22),
 ('生意', 20),
 ('老板', 20),
 ('鸡翅', 20),
 ('推荐', 18),
 ('喜欢', 18),
 ('五花肉', 18),
 ('海鲜', 18),
 ('安排', 16),
 ('可能', 16),
 ('还好', 16),
 ('肉类', 16),
 ('拥挤', 16),
 ('问题', 16),
 ('口味', 16),
 ('自助', 16),
 ('失望', 16),
 ('不会', 14),
 ('时间', 12),
 ('满意', 12),
 ('蔬菜', 12),
 ('品种', 12),
 ('实惠', 12),
 ('肥牛', 12),
 ('还行', 12),
 ('座位', 12),
 ('结果', 12),
 ('建议', 12),
 ('不到', 11),
 ('江南', 10),
 ('适合', 10),
 ('果汁', 10),
 ('出来', 10),
 ('总体', 10),
 ('聚餐', 10),
 ('朋友', 10),
 ('希望', 10),
 ('大家', 10),
 ('饮品', 10),
 ('地方', 10),
 ('拉肚子', 10),
 ('应该', 10),
 ('回去', 10),
 ('小吃', 10),
 ('爆满', 8),
 ('开心', 8),
 ('评价', 8),
 ('店家', 8),
 ('起来', 8),
 ('扇贝', 8),
 ('小时', 8),
 ('头发', 8),
 ('客人', 8),
 ('鸡腿', 8),
 ('需要', 8),
 ('消费', 8),
 ('调料', 8),
 ('开始', 8),
 ('用餐', 8),
 ('老板娘', 8),
 ('美团', 8),
 ('热情', 6),
 ('温江', 6),
 ('二楼', 6),
 ('勉强', 6),
 ('太小', 6),
 ('可惜', 6),
 ('坐在', 6),
 ('酒水', 6),
 ('不能', 6),
 ('空间', 6),
 ('生菜', 6),
 ('体验', 6),
 ('店里', 6),
 ('性价比', 6),
 ('煎蛋', 6),
 ('空调', 6),
 ('不想', 6),
 ('实在', 6),
 ('凉面', 6),
 ('个人', 6),
 ('质量', 6),
 ('准备', 6),
 ('供应', 6),
 ('同学', 6),
 ('食欲', 6),
 ('免费', 6),
 ('男服务员', 6),
 ('看到', 6),
 ('桌子', 4),
 ('估计', 4),
 ('遇到', 4),
 ('套餐', 4),
 ('基本上', 4),
 ('加油', 4),
 ('呵呵', 4),
 ('烤肉店', 4),
 ('一分货', 4),
 ('辣椒面', 4),
 ('蛋糕', 4),
 ('没得', 4),
 ('接受', 4),
 ('甜品', 4),
 ('不够', 4),
 ('牛肉', 4),
 ('补菜', 4),
 ('肚子', 4),
 ('定位', 4),
 ('炭火', 4),
 ('手机', 4),
 ('自助餐', 4),
 ('服务到位', 4),
 ('愿意', 4),
 ('事情', 4),
 ('涨价', 4),
 ('选择', 4),
 ('食物', 4),
 ('单人', 4),
 ('排队', 4),
 ('冰粉', 4),
 ('盘子', 4),
 ('显得', 4),
 ('酱料', 4),
 ('收银', 4),
 ('补充', 4),
 ('全部', 4),
 ('提供', 4),
 ('恶心', 4),
 ('肠胃', 4),
 ('端菜', 4),
 ('像是', 4),
 ('看起来', 4),
 ('一分钱', 4),
 ('烤熟', 4),
 ('异味', 4),
 ('价格便宜', 4),
 ('停电', 4),
 ('鳕鱼', 4),
 ('基本', 4),
 ('看着', 4),
 ('肯定', 4),
 ('说话', 4),
 ('只能', 4),
 ('肉品', 4),
 ('机会', 4),
 ('大湾', 4),
 ('油腻', 4),
 ('价格比', 4),
 ('发现', 4),
 ('晓得', 4),
 ('前台', 4),
 ('温度', 3),
 ('甜点', 3),
 ('挤死', 2),
 ('世界', 2),
 ('难受', 2),
 ('忧伤', 2),
 ('拿走', 2),
 ('控制', 2),
 ('太重', 2),
 ('珠江', 2),
 ('学生', 2),
 ('出钱', 2),
 ('没来', 2),
 ('吃货', 2),
 ('肚皮', 2),
 ('冷气', 2),
 ('衣服', 2),
 ('规模', 2),
 ('调低', 2),
 ('预订', 2),
 ('模式', 2),
 ('懒猫', 2),
 ('不吃', 2),
 ('改进', 2),
 ('火太', 2),
 ('红火', 2),
 ('说不出', 2),
 ('押金', 2),
 ('高质量', 2),
 ('品质', 2),
 ('臭味', 2),
 ('超能', 2),
 ('样子', 2),
 ('汽水', 2),
 ('筷子', 2),
 ('有没有', 2),
 ('男生', 2),
 ('油烟', 2),
 ('表示', 2),
 ('烤鸡', 2),
 ('嘴巴', 2),
 ('识别', 2),
 ('评差', 2),
 ('回家', 2),
 ('新增', 2),
 ('大学生', 2),
 ('忘记', 2),
 ('外形', 2),
 ('厕所', 2),
 ('评分', 2),
 ('理解', 2),
 ('宣传', 2),
 ('奶奶', 2),
 ('冰激凌', 2),
 ('用料', 2),
 ('零食', 2),
 ('起火', 2),
 ('说糊', 2),
 ('对面', 2),
 ('喊换', 2),
 ('入味', 2),
 ('发正', 2),
 ('好玩', 2),
 ('没钱', 2),
 ('学期', 2),
 ('帮助', 2),
 ('糖水', 2),
 ('聚会', 2),
 ('应急', 2),
 ('上放', 2),
 ('毛病', 2),
 ('收费', 2),
 ('挑战', 2),
 ('番茄', 2),
 ('教练', 2),
 ('腌制', 2),
 ('学校', 2),
 ('摇摇', 2),
 ('韩国', 2),
 ('鸡肉', 2),
 ('比电', 2),
 ('牌子', 2),
 ('变化', 2),
 ('差距', 2),
 ('烤完', 2),
 ('作料', 2),
 ('人流量', 2),
 ('没气', 2),
 ('价位', 2),
 ('得罪', 2),
 ('松散', 2),
 ('垃圾', 2),
 ('做出', 2),
 ('几毛钱', 2),
 ('可多', 2),
 ('加菜', 2),
 ('蝴蝶结', 2),
 ('好喝', 2),
 ('缺菜', 2),
 ('吃土', 2),
 ('还上', 2),
 ('失落', 2),
 ('进餐', 2),
 ('打扰', 2),
 ('诋毁', 2),
 ('疼痛', 2),
 ('冒充', 2),
 ('继续', 2),
 ('选菜', 2),
 ('改好', 2),
 ('情况', 2),
 ('貌似', 2),
 ('钢丝', 2),
 ('厨房', 2),
 ('情侣', 2),
 ('学妹', 2),
 ('白色', 2),
 ('点菜', 2),
 ('愤怒', 2),
 ('儿童', 2),
 ('基地', 2),
 ('通风', 2),
 ('现炸', 2),
 ('改变', 2),
 ('求求', 2),
 ('享受', 2),
 ('内类', 2),
 ('消费者', 2),
 ('新鲜度', 2),
 ('食品', 2),
 ('变动', 2),
 ('计较', 2),
 ('为难', 2),
 ('想要', 2),
 ('差评', 2),
 ('服用', 2),
 ('荤菜', 2),
 ('名字', 2),
 ('欲望', 2),
 ('太气', 2),
 ('新城', 2),
 ('唾沫', 2),
 ('芭蕾', 2),
 ('待会儿', 2),
 ('敷衍', 2),
 ('情人', 2),
 ('社团', 2),
 ('合计', 2),
 ('重点', 2),
 ('女的', 2),
 ('忍痛', 2),
 ('店面', 2),
 ('撒子', 2),
 ('腌渍', 2),
 ('毫无', 2),
 ('不算', 2),
 ('装菜', 2),
 ('带头作用', 2),
 ('回收', 2),
 ('妹子', 2),
 ('换回去', 2),
 ('端出来', 2),
 ('量产', 2),
 ('下雨', 2),
 ('特差', 2),
 ('记性', 2),
 ('照片', 2),
 ('毕业', 2),
 ('门面', 2),
 ('转移', 2),
 ('身子', 2),
 ('听说', 2),
 ('不理', 2),
 ('原因', 2),
 ('收钱', 2),
 ('科技兴农', 2),
 ('看看', 2),
 ('奶茶', 2),
 ('意思', 2),
 ('开家', 2),
 ('猪猪', 2),
 ('年头', 2),
 ('年轻人', 2),
 ('女服务员', 2),
 ('没人', 2),
 ('喷射', 2),
 ('餐厅', 2),
 ('烤生', 2),
 ('冻麻', 2),
 ('猪肉', 2),
 ('鹌鹑蛋', 2),
 ('印象', 2),
 ('打发', 2),
 ('肉食', 2),
 ('等到', 2),
 ('付费', 2),
 ('电话', 2),
 ('没了', 2),
 ('啤酒', 2),
 ('进去', 2),
 ('制作', 2),
 ('挨着', 2),
 ('打扫', 2),
 ('同事', 2),
 ('真话', 2),
 ('浓度', 2),
 ('等位', 2),
 ('吃到', 2),
 ('压抑', 2),
 ('全都', 2),
 ('泡芙', 2),
 ('扩大', 2),
 ('是从', 2),
 ('口感', 2),
 ('洗出来', 2),
 ('想象', 2),
 ('地段', 2),
 ('味碟', 2),
 ('人气', 2),
 ('样式', 2),
 ('商家', 2),
 ('点儿', 2),
 ('藕片', 2),
 ('开了', 2),
 ('需耗', 2),
 ('吓人', 2),
 ('解决', 2),
 ('还赖', 2),
 ('来得', 2),
 ('倒闭', 2),
 ('食材', 2),
 ('优惠', 2),
 ('点心', 2),
 ('水军', 2),
 ('火龙果', 2),
 ('喷壶', 2),
 ('蛋黄', 2),
 ('回头客', 2),
 ('挡风', 2),
 ('水味', 2),
 ('跟不上', 2),
 ('鸭肠', 2),
 ('数落', 2),
 ('价钱', 2),
 ('豆腐', 2),
 ('鸡蛋', 2),
 ('劣质', 2),
 ('无视', 2),
 ('欺凌', 2),
 ('橙汁', 2),
 ('节奏', 2),
 ('外场', 2),
 ('腌过', 2),
 ('了会', 2),
 ('不让', 2),
 ('恼火', 2),
 ('牛排', 2),
 ('色味', 2),
 ('一帮人', 2),
 ('打招呼', 2),
 ('块钱', 2),
 ('算是', 2),
 ('评论', 2),
 ('撑破', 2),
 ('沙包', 2),
 ('部分', 2),
 ('人山人海', 2),
 ('选购', 2),
 ('冷冻', 2),
 ('肉价', 2),
 ('水滴', 2),
 ('佐料', 2),
 ('烤号', 2),
 ('方面', 2),
 ('大学城', 2),
 ('不的', 2),
 ('老子', 2),
 ('叫换', 2),
 ('接冰', 2),
 ('下班', 2),
 ('卖家', 2),
 ('吃生', 2),
 ('重头戏', 2),
 ('难过', 2),
 ('失误', 2),
 ('泔水桶', 2),
 ('差点', 2),
 ('变成', 2),
 ('尝尝', 2),
 ('学习', 2),
 ('满足', 2),
 ('长点', 2),
 ('样数', 2),
 ('气氛', 2),
 ('点点', 2),
 ('观察', 2),
 ('值得', 2),
 ('选择性', 2),
 ('热度', 2),
 ('收拾', 2),
 ('预定', 2),
 ('走过', 2),
 ('火腿', 2),
 ('场地面积', 2),
 ('团购', 2),
 ('离开', 2),
 ('极差', 2),
 ('变少', 2),
 ('宿舍', 2),
 ('总得', 2),
 ('纸张', 2),
 ('电影', 2),
 ('带进去', 2),
 ('家人', 2),
 ('回来', 2),
 ('关键', 2),
 ('浪费', 2),
 ('干碟', 2),
 ('打算', 2),
 ('区域', 2),
 ('打车', 2),
 ('鸡汤', 2),
 ('果汁机', 2),
 ('氛围', 2),
 ('发黑', 2),
 ('扒手', 2),
 ('小看', 2),
 ('热天', 2),
 ('小小年纪', 2),
 ('架子', 2),
 ('男朋友', 2),
 ('穿过', 2),
 ('停车', 2),
 ('改善', 2),
 ('管饱', 2),
 ('素菜', 2),
 ('上当', 2),
 ('胃口', 2),
 ('洗碗', 2),
 ('小人', 2),
 ('想到', 2),
 ('屋顶', 2),
 ('芥末', 2),
 ('影响', 2),
 ('蛤蜊', 2),
 ('基围', 2),
 ('呕吐', 2),
 ('包治', 2),
 ('胖咯', 2),
 ('公司', 2),
 ('味儿', 2),
 ('收银台', 2),
 ('拍照片', 2),
 ('开店', 2),
 ('挑不出', 2),
 ('支付', 2),
 ('讲究', 2),
 ('拿菜', 2),
 ('习惯', 2),
 ('装修', 2),
 ('上火', 2),
 ('摆放', 2),
 ('光光', 2),
 ('受欢迎', 2),
 ('熟食', 2),
 ('惊呆', 2),
 ('新开', 2),
 ('能换', 2),
 ('红色', 2),
 ('关系', 2),
 ('指定', 2),
 ('教学班', 2),
 ('剪刀', 2),
 ('没法', 2),
 ('提前', 2),
 ('不太好', 2),
 ('变好', 2),
 ('吃饭', 2),
 ('鸡皮', 2),
 ('路过', 2),
 ('无语', 2),
 ('失败', 2),
 ('了来', 2),
 ('请客', 2),
 ('肉油', 2),
 ('颜色', 2),
 ('换成', 2),
 ('酸味', 2),
 ('后街', 2),
 ('提升', 2),
 ('花样', 2),
 ('小心', 2),
 ('兼职', 2),
 ('烤牛肉', 2),
 ('好人', 2),
 ('讲课', 2),
 ('糕点', 1)]

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType


def wordcloud_base() -> WordCloud:
    c = (
        WordCloud()
        .add("", words, word_size_range=[20, 100])
        .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
    )
    return c

wd = wordcloud_base()
wd.render()
# Out:
# 'F:\\FinancialIntelligence\\render.html'

# %%
from pyecharts import options as opts
from pyecharts.charts import PictorialBar
from pyecharts.globals import SymbolType

location = ["五花肉", "中翅", "西瓜", "味碟", "鸡腿",
            "鸡翅", "水果蔬菜", "冰淇淋", "烤鸡蛋", "果汁"][::-1]
values = [295, 168, 126, 124, 120, 118, 112, 95, 91, 88][::-1]

c = (
    PictorialBar()
    .add_xaxis(location)
    .add_yaxis(
        "",
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat="fixed",
        symbol_offset=[0, 0],
        is_symbol_clip=True,
        symbol=SymbolType.ROUND_RECT,
    )
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="积极评论推荐菜"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=False),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(opacity=0)
            ),
        ),
    )
    .render("积极评论推荐菜.html")
)

# %%
# 人气菜品好评和差评比例
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

# 积极
list2 = [
    {"value": 295, "percent": 295 / (295 + 24)},
    {"value": 168, "percent": 168 / (168 + 16)},
    {"value": 126, "percent": 126 / (126 + 16)},
    {"value": 118, "percent": 118 / (118 + 14)},
    {"value": 124, "percent": 124 / (124 + 8)},
]

# 消极
list3 = [
    {"value": 24, "percent": 24 / (295 + 24)},
    {"value": 16, "percent":16 / (168 + 16)},
    {"value": 16, "percent": 16 / (126 + 16)},
    {"value": 14, "percent": 14 / (118 + 14)},
    {"value": 8, "percent": 8 / (124 + 8)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(['五花肉', '中翅', '西瓜', '鸡翅', '味碟'])
    .add_yaxis("好评", list2, stack="stack1", category_gap="50%")
    .add_yaxis("差评", list3, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
    .render("人气菜品好评与差评比例.html")
)

# %%
import pyecharts.options as opts
from pyecharts.charts import Line, Grid
from pyecharts.commons.utils import JsCode

"""
参考地址: https://gallery.echartsjs.com/editor.html?c=xEyDk1hwBx
"""

x_data = ["300条", "500条", "500条", "500条", "500条", "500条"]
y_data = [93.6, 87.2, 84, 84, 84.2, 87.2]

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="注册总量",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="OCTOBER 2015",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

(
    Grid()
    .add(
        c,
        grid_opts=opts.GridOpts(
            pos_top="20%",
            pos_left="10%",
            pos_right="10%",
            pos_bottom="15%",
            is_contain_label=True,
        ),
    )
    .render("江南道情感值变化.html")
)
# Out:
# 'F:\\FinancialIntelligence\\江南道情感值变化.html'

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode


x_data = ["300", "500", "500", "500", "500", "500"]
y_data = [93.6, 87.2, 84, 84, 84.2, 87.2]

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="注册总量",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="OCTOBER 2015",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .render("jnd_sent.html")
)

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker
x_data = ["300", "500", "500", "500", "500", "500"]
y_data = [93.6, 87.2, 84, 84, 84.2, 87.2]
c = (
    Line()
    .add_xaxis(x_data)
    .add_yaxis("江南道情感值", y_data, is_smooth=True)
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-smooth"))
    .render("line_smooth.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker
lst = [
 ('韩国小胖料理自助烤肉', 0.8936535162950258),
 ('北木南烤肉和酒（西南财大店）', 0.8815489749430524),
 ('韩婆婆小院烧烤', 0.8692893401015228),
 ('大美蓉城自助火锅烤肉（温江店）', 0.8645092460881935),
 ('江南道自助烤肉海鲜涮锅（柳浪湾店）', 0.8602383531960996),
 ('韩呈一品韩式自助（温江店）', 0.8403041825095057),
 ('众里寻她·千百度自助烤肉（温江店）', 0.7794830371567044)]

x_data = []
y_data = []
for ll in lst:
    x_data.append(ll[0])
    y_data.append(ll[1]*100)
c = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis("店铺情感值", y_data, color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-DataZoom（inside）"),
        datazoom_opts=opts.DataZoomOpts(type_="inside"),
    )
    .set_global_opts(yaxis_opts=opts.AxisOpts(min_=70))
    .render("七家同类商店的情感值.html")
)
