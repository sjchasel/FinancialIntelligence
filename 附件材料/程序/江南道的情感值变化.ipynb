# %%
import pandas as pd
import numpy as np
import tqdm
from tqdm import tqdm
from tqdm import trange
import re

# %%
jnd = pd.read_csv('jnd_sent.csv')
jnd
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1               店铺名称  \
# 0              0         28784               0  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 1              1         28785               1  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 2              2         28786               2  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 3              3         28787               3  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 4              4         28788               4  江南道自助烤肉海鲜涮锅（柳浪湾店）
# ...          ...           ...             ...                ...
# 2827        2827         35302            2645  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 2828        2828         35303            2646  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 2829        2829         35304            2647  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 2830        2830         35305            2648  江南道自助烤肉海鲜涮锅（柳浪湾店）
# 2831        2831         35306            2649  江南道自助烤肉海鲜涮锅（柳浪湾店）
#
#                用户名                                                 评论  scores  \
# 0     vZs846144283  在西财那边和新尚天地这里的都吃过，味道真的一绝，特别是里面各种肉类，超级美味，寝室团建我们可...  14.800
# ...

# %%
print(jnd[:500]['res'].value_counts())
print(jnd[500:1000]['res'].value_counts())
print(jnd[1000:1500]['res'].value_counts())
print(jnd[1500:2000]['res'].value_counts())
print(jnd[2000:2500]['res'].value_counts())
print(jnd[2500:2800]['res'].value_counts())
# Out:
#  1    436
# -1     64
# Name: res, dtype: int64
#  1    421
# -1     79
# Name: res, dtype: int64
#  1    420
# -1     80
# Name: res, dtype: int64
#  1    420
# -1     80
# Name: res, dtype: int64
#  1    436
# -1     64
# Name: res, dtype: int64
#  1    281
# -1     19
# Name: res, dtype: int64
